# %% [markdown]
# <a href="https://colab.research.google.com/github/jovanniochoa/MachineLearningVisualization/blob/Testing/music_mood_classifier_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import os
import IPython

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d kingofarmy/musical-emotions-classification
# Out:
# ...
#  97% 623M/641M [00:08<00:00, 92.0MB/s]
# 100% 641M/641M [00:08<00:00, 75.5MB/s]

# %%
# !unzip /content/musical-emotions-classification.zip
# Out:
# Archive:  /content/musical-emotions-classification.zip
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43600.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43601.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43602.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43603.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43604.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43605.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43606.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43607.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43608.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43609.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43610.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43611.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43612.wav
#   inflating: Audio_Files/Audio_Files/Test/Happy/Happy43613.wav
# ...

# %%
test_dir = "/content/Audio_Files/Audio_Files/Test"
train_dir = '/content/Audio_Files/Audio_Files/Train'

# %%
def create_df(dir):
  target = []
  audio = []
  for i in os.listdir(dir) :
    if i == 'Sad':
      for i in os.listdir(dir+'/'+'Sad') : 
        target.append('sad')
        audio.append(dir+'/'+'Sad'+'/'+i) 
    else:
      for i in os.listdir(dir+'/'+'Happy') : 
        target.append('happy')
        audio.append(dir+'/'+'Happy'+'/'+i) 
    df = pd.DataFrame(columns=['audio','target'])
    df['audio'] = audio
    df['target'] = target
  return df

# %%
train_df = create_df(train_dir)
train_df.shape
# Out:
# (1873, 2)

# %%
train_df
# Out:
#                                                   audio target
# 0     /content/Audio_Files/Audio_Files/Train/Happy/H...  happy
# 1     /content/Audio_Files/Audio_Files/Train/Happy/H...  happy
# 2     /content/Audio_Files/Audio_Files/Train/Happy/H...  happy
# 3     /content/Audio_Files/Audio_Files/Train/Happy/H...  happy
# 4     /content/Audio_Files/Audio_Files/Train/Happy/H...  happy
# ...                                                 ...    ...
# 1868  /content/Audio_Files/Audio_Files/Train/Sad/Sad...    sad
# 1869  /content/Audio_Files/Audio_Files/Train/Sad/Sad...    sad
# 1870  /content/Audio_Files/Audio_Files/Train/Sad/Sad...    sad
# 1871  /content/Audio_Files/Audio_Files/Train/Sad/Sad...    sad
# 1872  /content/Audio_Files/Audio_Files/Train/Sad/Sad...    sad
#
# [1873 rows x 2 columns]

# %%
test_df = create_df(test_dir)
test_df.shape
# Out:
# (253, 2)

# %%
train_df['target'].value_counts()
# Out:
# sad      1045
# happy     828
# Name: target, dtype: int64

# %%
x = 1603
print(train_df.iloc[x,1])
IPython.display.Audio(train_df.iloc[x,0])
# Out:
# sad
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
